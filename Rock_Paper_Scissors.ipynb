# %%
import random

options = ("rock", "paper", "scissors")
score = 0
active = True

while active:

    user = input("Choice (rock/paper/scissors/quit): ").lower()
    
    if user == "quit":
        active = False
        continue

    if user not in options:
        print(f"Invalid choice!")
        continue
        
    comp = random.choice(options)
    print(f"Computer chose: {comp}")

    if user == comp:
        print("It's a tie!")
    elif (user == "rock" and comp == "scissors") or \
         (user == "paper" and comp == "rock") or \
         (user == "scissors" and comp == "paper"):
        score += 1
        print("You win!")
    else:
        print("You lose!")
print(f"Total Score: {score}")
# Out:
# Choice (rock/paper/scissors/quit):  rock
# Computer chose: rock
# It's a tie!
# Choice (rock/paper/scissors/quit):  paper
# Computer chose: rock
# You win!
# Choice (rock/paper/scissors/quit):  quit
